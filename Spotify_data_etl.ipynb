# %%
# !pip3 install spotipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
# Initialize Spotify client with client credentials
client_credentials_manager = SpotifyClientCredentials(client_id="#Enter client Id here", client_secret="#Enter secret Id here")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
# Define the link to the playlist
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"

# %%
print(playlist_link.split("/")[-1].split('?')[0])

playlist_URI = playlist_link.split("/")[-1].split('?')[0]
# Out:
# 37i9dQZEVXbMDoHDwVN2tF

# %%
# Fetch track data from the playlist
data = sp.playlist_tracks(playlist_URI)

# %%
data['items']
# Out:
# [{'added_at': '2023-08-13T09:30:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#       'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#       'id': '6HaGTQPmzraVmaVxvz6EUc',
#       'name': 'Jung Kook',
#       'type': 'artist',
#       'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'},
#       'href': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ',
#       'id': '3MdXrJWsbVzdn6fe5JYkSQ',
#       'name': 'Latto',
#       'type': 'artist',
#       'uri': 'spotify:artist:3MdXrJWsbVzdn6fe5JYkSQ'}],
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '53985D8g3JcGBoULSOYYKX'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Seven (feat. Latto)'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-07-14'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 3

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/53985D8g3JcGBoULSOYYKX'

# %%
#Extracting and oragnizing album information from dataset using a list if dictionaries
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
# Structured data
album_list
# Out:
# [{'album_id': '53985D8g3JcGBoULSOYYKX',
#   'name': 'Seven (feat. Latto)',
#   'release_date': '2023-07-14',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/53985D8g3JcGBoULSOYYKX'},
#  {'album_id': '3puAvurwvtvi1rodndIPW8',
#   'name': 'LA VIDA ES UNA',
#   'release_date': '2023-03-23',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/3puAvurwvtvi1rodndIPW8'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'name': 'Lover',
#   'release_date': '2019-08-23',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_id': '3AafSrFIbJPH6BJHiJm1Cd',
#   'name': 'What Was I Made For? [From The Motion Picture "Barbie"]',
#   'release_date': '2023-07-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3AafSrFIbJPH6BJHiJm1Cd'},
#  {'album_id': '5cH7FqB7JD5q1tJXJ7FHYu',
#   'name': 'Dance The Night (From Barbie The Album)',
#   'release_date': '2023-05-25',
#   'total_tracks': 1,
# ...

# %%
#Extracting and oragnizing artist information from dataset using a list if dictionaries
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '6HaGTQPmzraVmaVxvz6EUc',
#   'artist_name': 'Jung Kook',
#   'external_url': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc'},
#  {'artist_id': '3MdXrJWsbVzdn6fe5JYkSQ',
#   'artist_name': 'Latto',
#   'external_url': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ'},
#  {'artist_id': '7iK8PXO48WeuP03g8YR51W',
#   'artist_name': 'Myke Towers',
#   'external_url': 'https://api.spotify.com/v1/artists/7iK8PXO48WeuP03g8YR51W'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '6M2wZ9GZgrQXHCFfjv46we',
#   'artist_name': 'Dua Lipa',
#   'external_url': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
# ...

# %%
#Extracting and oragnizing songs information from dataset using a list if dictionaries
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
# Create DataFrame for album information and remove duplicates
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  53985D8g3JcGBoULSOYYKX                                Seven (feat. Latto)
# 1  3puAvurwvtvi1rodndIPW8                                     LA VIDA ES UNA
# 2  1NAmidJlEaVgA3MpcPFYGq                                              Lover
# 3  3AafSrFIbJPH6BJHiJm1Cd  What Was I Made For? [From The Motion Picture ...
# 4  5cH7FqB7JD5q1tJXJ7FHYu            Dance The Night (From Barbie The Album)
#
#   release_date  total_tracks  \
# 0   2023-07-14             3
# 1   2023-03-23            23
# 2   2019-08-23            18
# 3   2023-07-13             1
# 4   2023-05-25             1
#
#                                                  url
# 0  https://open.spotify.com/album/53985D8g3JcGBoU...
# 1  https://open.spotify.com/album/3puAvurwvtvi1ro...
# 2  https://open.spotify.com/album/1NAmidJlEaVgA3M...
# 3  https://open.spotify.com/album/3AafSrFIbJPH6BJ...
# 4  https://open.spotify.com/album/5cH7FqB7JD5q1tJ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
# Create DataFrame for artist information and remove duplicates
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
# Create DataFrame for songs information and remove duplicates
song_df = pd.DataFrame.from_dict(song_list)

# %% [markdown]
# Displaying the converted Json data into a dataframes structured format

# %%
song_df.head()
# Out:
#                   song_id                                          song_name  \
# 0  7x9aauaA9cu6tyfpHnqDLo                Seven (feat. Latto) (Explicit Ver.)
# 1  7ABLbnD53cQK00mhcaOUVG                                               LALA
# 2  1BxfuPKGuaTgP7aM0Bbdwr                                       Cruel Summer
# 3  6wf7Yu7cxBSPrRlWeSeK0Q  What Was I Made For? [From The Motion Picture ...
# 4  1vYXt7VSjH9JIM5oRRo7vA            Dance The Night (From Barbie The Album)
#
#    duration_ms                                                url  popularity  \
# 0       184400  https://open.spotify.com/track/7x9aauaA9cu6tyf...         100
# 1       197920  https://open.spotify.com/track/7ABLbnD53cQK00m...          99
# 2       178426  https://open.spotify.com/track/1BxfuPKGuaTgP7a...          99
# 3       222369  https://open.spotify.com/track/6wf7Yu7cxBSPrRl...          98
# 4       176579  https://open.spotify.com/track/1vYXt7VSjH9JIM5...          97
#
# ...

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  6HaGTQPmzraVmaVxvz6EUc      Jung Kook
# 1  3MdXrJWsbVzdn6fe5JYkSQ          Latto
# 2  7iK8PXO48WeuP03g8YR51W    Myke Towers
# 3  06HL4z0CvFAxyc27GXpf02   Taylor Swift
# 4  6qqNVTkY8uBg9cP3Jd7DAH  Billie Eilish
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 1  https://api.spotify.com/v1/artists/3MdXrJWsbVz...
# 2  https://api.spotify.com/v1/artists/7iK8PXO48We...
# 3  https://api.spotify.com/v1/artists/06HL4z0CvFA...
# 4  https://api.spotify.com/v1/artists/6qqNVTkY8uB...

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  53985D8g3JcGBoULSOYYKX                                Seven (feat. Latto)
# 1  3puAvurwvtvi1rodndIPW8                                     LA VIDA ES UNA
# 2  1NAmidJlEaVgA3MpcPFYGq                                              Lover
# 3  3AafSrFIbJPH6BJHiJm1Cd  What Was I Made For? [From The Motion Picture ...
# 4  5cH7FqB7JD5q1tJXJ7FHYu            Dance The Night (From Barbie The Album)
#
#   release_date  total_tracks  \
# 0   2023-07-14             3
# 1   2023-03-23            23
# 2   2019-08-23            18
# 3   2023-07-13             1
# 4   2023-05-25             1
#
#                                                  url
# 0  https://open.spotify.com/album/53985D8g3JcGBoU...
# 1  https://open.spotify.com/album/3puAvurwvtvi1ro...
# 2  https://open.spotify.com/album/1NAmidJlEaVgA3M...
# 3  https://open.spotify.com/album/3AafSrFIbJPH6BJ...
# 4  https://open.spotify.com/album/5cH7FqB7JD5q1tJ...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
